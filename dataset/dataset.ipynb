# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 한국어 단발성 대화 데이터셋 [column명 변경]

# %%
import pandas as pd
data1 = pd.read_excel('/content/drive/MyDrive/dataset/한국어_단발성_대화_데이터셋.xlsx')

# %%
len(data1)
data1.sample(n=10)

# %%
# Sentence와 Emotion 2개의 열 선택
data1 = data1.iloc[:, :2]

# %%
#칼럼 이름 바꾸기
data1.rename(columns={"Sentence" :"문장", "Emotion":"감정"}, inplace=True)

# %% [markdown]
# ## 감성 대화 말뭉치

# %%
data2 = pd.read_excel('/content/drive/MyDrive/dataset/감성대화말뭉치(최종데이터)_Training.xlsx')
data3 = pd.read_excel('/content/drive/MyDrive/dataset/감성대화말뭉치(최종데이터)_Validation.xlsx')

# %%
len(data2)

# %%
len(data3)

# %%
data2.sample(n=1)
# Out:
#       Unnamed: 0  연령  성별 상황키워드  신체질환 감정_대분류 감정_소분류  \
# 7426        7427  청년  여성  대인관계  해당없음     불안     불안
#
#                                          사람문장1                     시스템문장1  \
# 7426  요즘에 전화가 오면 불안해. 별로 통화하고 싶지 않고 문자만 하고 싶어.  전화가 오면 불안하시는군요. 무슨 일이신가요?
#
#                                              사람문장2  \
# 7426  별로 친하지 않은 사람들에게 전화가 오면 막 피하고 싶어져. 조금 부담스럽거든.
#
#                                       시스템문장2 사람문장3 시스템문장3
# 7426  친밀하지 않은 사람과 전화하는 데 있어서 부담감을 느끼고 계시는군요.   NaN    NaN

# %%
data3.sample(n=1)
# Out:
#       Unnamed: 0   연령  성별 상황키워드  신체질환 감정_대분류 감정_소분류  \
# 1080        1081  청소년  남성  가족관계  해당없음     상처  충격 받은
#
#                                             사람문장1  \
# 1080  물건을 하나를 잃어버렸는데 그게 누나 남자 친구한테 있었어. 너무 충격받았어.
#
#                                        시스템문장1  \
# 1080  잃어버리신 물건이 누나의 남자 친구가 가지고 있어서 충격이 크시겠어요.
#
#                                          사람문장2  \
# 1080  누나가 내 물건을 모르고 남자 친구에게 준 걸까? 어떻게 그럴 수 있지?
#
#                                   시스템문장2  \
# 1080  누나가 의심되시나 봐요. 누나에게 솔직하게 물어보면 어떨까요?
#
#                                               사람문장3                  시스템문장3
# 1080  누나에게 말해야겠어. 내 물건 같으니 돌려달라고 말하는 게 좋은 방법인 것 같아.  대화를 통해서 잘 해결되었으면 좋겠어요.

# %%
# 누락된 NaN의 경우 빈 문자열로 대체
data2 = data2.fillna('')
data3 = data3.fillna('')

# %%
# 사람문장1, 2, 3을 하나의 열로 합치기
data2['사람문장'] = data2[['사람문장1', '사람문장2', '사람문장3']].apply(lambda row: ' '.join(row), axis=1)
data3['사람문장'] = data3[['사람문장1', '사람문장2', '사람문장3']].apply(lambda row: ' '.join(row), axis=1)

# %%
data2.sample(n=1)
# Out:
#       Unnamed: 0   연령  성별     상황키워드  신체질환 감정_대분류 감정_소분류  \
# 1773        1774  청소년  남성  학교폭력/따돌림  해당없음     기쁨     흥분
#
#                                       사람문장1                       시스템문장1  \
# 1773  오늘 학교에 가지 않았는데 많은 아이들이 걱정하는 문자를 보내왔어.  많은 아이들에게 연락을 받아서 기분이 어떠셨나요?
#
#                                사람문장2  \
# 1773  나를 그렇게나 신경 써주고 있었구나 싶어서 좀 기뻤어.
#
#                                                  시스템문장2  \
# 1773  친구들이 신경 써주고 있다는 사실에 기쁘셨군요. 이 기쁨을 어떻게 표현하는 게 좋을까요?
#
#                        사람문장3               시스템문장3  \
# 1773  친구에게 편지를 써서 고마움을 표현할래.  고마움의 편지를 쓰려고 하시는군요.
#
#                                                    사람문장
# 1773  오늘 학교에 가지 않았는데 많은 아이들이 걱정하는 문자를 보내왔어. 나를 그렇게나 ...

# %%
data3.sample(n=1)
# Out:
#       Unnamed: 0  연령  성별 상황키워드  신체질환 감정_대분류 감정_소분류  \
# 3187        3188  중년  남성    건강  해당없음     상처  충격 받은
#
#                                          사람문장1  \
# 3187  잘 살려고 컴퓨터 앞에서 일한 건데 내 손목은 잘 지내지 못하게 되었어.
#
#                                시스템문장1  \
# 3187  성실히 산 것뿐인데 손목에 문제가 생겨서 억울하시겠군요.
#
#                                                   사람문장2  \
# 3187  성실하고 멋진 좋은 직원이 되고 동료가 되고 가족이 되려고 한 것뿐이었는데. 나 자...
#
#                                                  시스템문장2  \
# 3187  나 자신을 생각하지 않았다고 생각하시는군요. 어떻게 하면 이 상황에서 벗어날 수 있...
#
#                                          사람문장3                        시스템문장3  \
# 3187  목표를 구체적으로 다시 정하고 자신을 돌보는 것을 우선순위로 두어야겠어.  자신을 우선순위로 두어서 건강하게 행복하길 바라요.
#
#                                                    사람문장
# 3187  잘 살려고 컴퓨터 앞에서 일한 건데 내 손목은 잘 지내지 못하게 되었어. 성실하고 ...

# %%
# '사람문장1', '사람문장2', '사람문장3' 열 삭제
data2.drop(['사람문장1', '사람문장2', '사람문장3'], axis=1, inplace=True)
data3.drop(['사람문장1', '사람문장2', '사람문장3'], axis=1, inplace=True)

# '시스템문장1', '시스템문장2', '시스템문장3' 열 삭제
data2.drop(['시스템문장1', '시스템문장2', '시스템문장3'], axis=1, inplace=True)
data3.drop(['시스템문장1', '시스템문장2', '시스템문장3'], axis=1, inplace=True)

# '연령', '성별', '상황키워드', '신체질환' 열 삭제
data2.drop(['연령', '성별', '상황키워드', '신체질환', 'Unnamed: 0'], axis=1, inplace=True)
data3.drop(['연령', '성별', '상황키워드', '신체질환', 'Unnamed: 0'], axis=1, inplace=True)

# %%
data2.sample(n=1)
# Out:
#       감정_대분류 감정_소분류                                               사람문장
# 12614     분노   짜증내는  내가 지원했던 회사마다 다 날 탈락시켰는데 이유를 모르겠어. 가고자 했던 곳은 다 ...

# %%
data3.sample(n=1)
# Out:
#      감정_대분류 감정_소분류                                               사람문장
# 2722     당황  혼란스러운  나 너무 당황스러워. 어지러움을 느껴서 진찰을 받았는데 내가 파킨슨병이래. 파킨슨병...
